# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.initializers import glorot_uniform
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/dev dataset/train_data.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/dev dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[0]
#  [7]
#  [4]
#  [9]
#  [1]]
# Labels : [[7]
#  [2]
#  [0]
#  [8]
#  [7]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (18000, 32, 32)
# (3750, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 18000 images
# Test Set Size = 3750 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def four_conv_pool(x, F1, F2, F3, F4, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F4, (3, 3), activation=None, padding='same', name='{}_conv4'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        
        # Zero-Padding
        net = ZeroPadding2D((3, 3))(X_input)


        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = four_conv_pool(net, 256, 256, 256, 256, "block3")
        net = four_conv_pool(net, 512, 512, 512, 512, "block4")
        #net = four_conv_pool(net, 512, 512, 512, 512, "block5")


        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)
        
        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg19')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model_n = vggModel()
model_n.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv4 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 16,902,602
# Trainable params: 16,895,690
# Non-trainable params: 6,912
# _________________________________________________________________

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 282/282 [==============================] - 50s 151ms/step - loss: 1.5657 - accuracy: 0.4529 - val_loss: 4.6048 - val_accuracy: 0.1939
# Epoch 2/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.1420 - accuracy: 0.9582 - val_loss: 0.0872 - val_accuracy: 0.9808
# Epoch 3/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0620 - accuracy: 0.9835 - val_loss: 0.0901 - val_accuracy: 0.9784
# Epoch 4/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0517 - accuracy: 0.9866 - val_loss: 0.2045 - val_accuracy: 0.9536
# Epoch 5/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0470 - accuracy: 0.9882 - val_loss: 0.0648 - val_accuracy: 0.9880
# Epoch 6/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0382 - accuracy: 0.9908 - val_loss: 0.1083 - val_accuracy: 0.9763
# Epoch 7/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0204 - accuracy: 0.9947 - val_loss: 0.1852 - val_accuracy: 0.9621
# Epoch 8/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0303 - accuracy: 0.9929 - val_loss: 0.0881 - val_accuracy: 0.9829
# Epoch 9/100
# 282/282 [==============================] - 41s 145ms/step - loss: 0.0327 - accuracy: 0.9927 - val_loss: 0.1757 - val_accuracy: 0.9685
# Epoch 10/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0248 - accuracy: 0.9946 - val_loss: 0.1656 - val_accuracy: 0.9712
# Epoch 11/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0337 - accuracy: 0.9927 - val_loss: 0.0553 - val_accuracy: 0.9912
# Epoch 12/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0275 - accuracy: 0.9946 - val_loss: 0.0730 - val_accuracy: 0.9875
# Epoch 13/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0289 - accuracy: 0.9944 - val_loss: 0.0957 - val_accuracy: 0.9835
# Epoch 14/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0329 - accuracy: 0.9936 - val_loss: 0.1345 - val_accuracy: 0.9821
# Epoch 15/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0249 - accuracy: 0.9954 - val_loss: 0.1031 - val_accuracy: 0.9829
# Epoch 16/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0167 - accuracy: 0.9969 - val_loss: 0.0689 - val_accuracy: 0.9901
# Epoch 17/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0221 - accuracy: 0.9955 - val_loss: 0.0818 - val_accuracy: 0.9864
# Epoch 18/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0203 - accuracy: 0.9962 - val_loss: 0.1653 - val_accuracy: 0.9645
# Epoch 19/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0365 - accuracy: 0.9929 - val_loss: 0.0706 - val_accuracy: 0.9912
# Epoch 20/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0223 - accuracy: 0.9963 - val_loss: 0.0995 - val_accuracy: 0.9851
# Epoch 21/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0207 - accuracy: 0.9966 - val_loss: 0.0501 - val_accuracy: 0.9899
# Epoch 22/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.1466 - val_accuracy: 0.9813
# Epoch 23/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0336 - accuracy: 0.9939 - val_loss: 0.0479 - val_accuracy: 0.9915
# Epoch 24/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0224 - accuracy: 0.9958 - val_loss: 0.0426 - val_accuracy: 0.9933
# Epoch 25/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0376 - accuracy: 0.9932 - val_loss: 0.0570 - val_accuracy: 0.9867
# Epoch 26/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0171 - accuracy: 0.9973 - val_loss: 0.1355 - val_accuracy: 0.9837
# Epoch 27/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0152 - accuracy: 0.9975 - val_loss: 0.0865 - val_accuracy: 0.9899
# Epoch 28/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.2492 - val_accuracy: 0.9776
# Epoch 29/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0189 - accuracy: 0.9969 - val_loss: 0.1044 - val_accuracy: 0.9861
# Epoch 30/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0408 - accuracy: 0.9929 - val_loss: 0.0425 - val_accuracy: 0.9920
# Epoch 31/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.1021 - val_accuracy: 0.9893
# Epoch 32/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0313 - accuracy: 0.9948 - val_loss: 0.0597 - val_accuracy: 0.9931
# Epoch 33/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.0633 - val_accuracy: 0.9912
# Epoch 34/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 0.0666 - val_accuracy: 0.9891
# Epoch 35/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0105 - accuracy: 0.9980 - val_loss: 0.0705 - val_accuracy: 0.9925
# Epoch 36/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.0690 - val_accuracy: 0.9912
# Epoch 37/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.0681 - val_accuracy: 0.9925
# Epoch 38/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0166 - accuracy: 0.9967 - val_loss: 0.0447 - val_accuracy: 0.9941
# Epoch 39/100
# 282/282 [==============================] - 41s 146ms/step - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.2076 - val_accuracy: 0.9877
# Epoch 40/100
# 282/282 [==============================] - 42s 148ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.0874 - val_accuracy: 0.9928
# Epoch 41/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0124 - accuracy: 0.9982 - val_loss: 0.1072 - val_accuracy: 0.9917
# Epoch 42/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.1026 - val_accuracy: 0.9896
# Epoch 43/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0249 - accuracy: 0.9965 - val_loss: 0.1057 - val_accuracy: 0.9907
# Epoch 44/100
# 282/282 [==============================] - 42s 147ms/step - loss: 0.0237 - accuracy: 0.9964 - val_loss: 0.1321 - val_accuracy: 0.9923
# Epoch 45/100
# 282/282 [==============================] - 42s 148ms/step - loss: 0.0239 - accuracy: 0.9957 - val_loss: 0.1023 - val_accuracy: 0.9883
# Epoch 46/100
# 282/282 [==============================] - 42s 147ms/step - loss: 0.0083 - accuracy: 0.9985 - val_loss: 0.0794 - val_accuracy: 0.9904
# Epoch 47/100
# 282/282 [==============================] - 42s 147ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0368 - val_accuracy: 0.9949
# Epoch 48/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 0.2547 - val_accuracy: 0.9829
# Epoch 49/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.1391 - val_accuracy: 0.9893
# Epoch 50/100
# 282/282 [==============================] - 42s 147ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.0990 - val_accuracy: 0.9901
# Epoch 51/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.1728 - val_accuracy: 0.9821
# Epoch 52/100
# 282/282 [==============================] - 42s 148ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0783 - val_accuracy: 0.9931
# Epoch 53/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0299 - accuracy: 0.9968 - val_loss: 0.0688 - val_accuracy: 0.9917
# Epoch 54/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0080 - accuracy: 0.9983 - val_loss: 0.0476 - val_accuracy: 0.9920
# Epoch 55/100
# 282/282 [==============================] - 41s 147ms/step - loss: 9.3732e-04 - accuracy: 0.9998 - val_loss: 0.0487 - val_accuracy: 0.9933
# Epoch 56/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0122 - accuracy: 0.9986 - val_loss: 0.0938 - val_accuracy: 0.9925
# Epoch 57/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0253 - accuracy: 0.9964 - val_loss: 0.0429 - val_accuracy: 0.9936
# Epoch 58/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0141 - accuracy: 0.9982 - val_loss: 0.0618 - val_accuracy: 0.9912
# Epoch 59/100
# 282/282 [==============================] - 41s 147ms/step - loss: 7.9363e-04 - accuracy: 0.9998 - val_loss: 0.0690 - val_accuracy: 0.9928
# Epoch 60/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.0459 - val_accuracy: 0.9933
# Epoch 61/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0680 - val_accuracy: 0.9944
# Epoch 62/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.1954 - val_accuracy: 0.9877
# Epoch 63/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 0.1296 - val_accuracy: 0.9867
# Epoch 64/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0498 - val_accuracy: 0.9955
# Epoch 65/100
# 282/282 [==============================] - 41s 147ms/step - loss: 2.6806e-04 - accuracy: 0.9999 - val_loss: 0.0604 - val_accuracy: 0.9960
# Epoch 66/100
# 282/282 [==============================] - 41s 147ms/step - loss: 2.3067e-05 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9955
# Epoch 67/100
# 282/282 [==============================] - 41s 147ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1447 - val_accuracy: 0.9915
# Epoch 00067: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.998, Test accuracy: 0.991

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.14666666666666 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[4]
#  [9]
#  [6]
#  [5]
#  [4]]
# classified as: [2 6 9 6 2]
# True:          [[4]
#  [4]
#  [9]
#  [5]
#  [2]]
# classified as: [6 9 6 7 9]
