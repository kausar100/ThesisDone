# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.models import Model

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
y_test_ = y_test
print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
print(x_train.shape)
print(x_test.shape)
# Out:
# Train Set Size = 60000 images
# Test Set Size = 10000 images
# (60000, 28, 28)
# (10000, 28, 28)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
print(x_train.shape)
print(x_test.shape)

# expand new axis, channel axis 
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# it's always better to normalize 
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255


# resize the input shape , i.e. old shape: 28, new shape: 32
x_train = tf.image.resize(x_train, [32,32]) # if we want to resize 
x_test = tf.image.resize(x_test, [32,32]) # if we want to resize 

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 32, 32, 1)
# (10000, 32, 32, 1)

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = list((map(reshaping,x_train)))
x_train = np.array(a)

b = list((map(reshaping,x_test)))
x_test = np.array(b)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 32, 32)
# (10000, 32, 32)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
from  keras.utils import np_utils
y_train = to_categorical(y_train, num_classes=10, dtype='float32')
y_test = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 60000 images
# Test Set Size = 10000 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def four_conv_pool(x, F1, F2, F3, F4, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F4, (3, 3), activation=None, padding='same', name='{}_conv4'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        
        # Zero-Padding
        net = ZeroPadding2D((3, 3))(X_input)


        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = four_conv_pool(net, 256, 256, 256, 256, "block3")
        net = four_conv_pool(net, 512, 512, 512, 512, "block4")
        #net = four_conv_pool(net, 512, 512, 512, 512, "block5")


        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)
        
        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg19')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model = vggModel()
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv4 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 16,902,602
# Trainable params: 16,895,690
# Non-trainable params: 6,912
# _________________________________________________________________

# %%
batch_size = 64
num_epoch = 200

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = ModelCheckpoint('/content/drive/MyDrive/model/vgg19_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

#model training
ret = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,
          #validation_split=0.25,
          validation_data=(x_test, y_test),
          callbacks=[es, mc])
# Out:
# Epoch 1/200
# 938/938 [==============================] - 111s 114ms/step - loss: 0.5091 - accuracy: 0.8324 - val_loss: 0.1886 - val_accuracy: 0.9519
# Epoch 2/200
# 938/938 [==============================] - 107s 114ms/step - loss: 0.0933 - accuracy: 0.9776 - val_loss: 0.1106 - val_accuracy: 0.9799
# Epoch 3/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0728 - accuracy: 0.9825 - val_loss: 0.1025 - val_accuracy: 0.9731
# Epoch 4/200
# 938/938 [==============================] - 105s 112ms/step - loss: 0.0665 - accuracy: 0.9848 - val_loss: 0.0919 - val_accuracy: 0.9800
# Epoch 5/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0625 - accuracy: 0.9860 - val_loss: 0.1539 - val_accuracy: 0.9689
# Epoch 6/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0616 - accuracy: 0.9870 - val_loss: 0.0536 - val_accuracy: 0.9881
# Epoch 7/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0512 - accuracy: 0.9883 - val_loss: 0.0564 - val_accuracy: 0.9878
# Epoch 8/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0527 - accuracy: 0.9889 - val_loss: 0.0541 - val_accuracy: 0.9868
# Epoch 9/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0440 - accuracy: 0.9901 - val_loss: 0.0853 - val_accuracy: 0.9839
# Epoch 10/200
# 938/938 [==============================] - 105s 112ms/step - loss: 0.0410 - accuracy: 0.9909 - val_loss: 0.0358 - val_accuracy: 0.9919
# Epoch 11/200
# 938/938 [==============================] - 105s 112ms/step - loss: 0.0346 - accuracy: 0.9924 - val_loss: 0.0332 - val_accuracy: 0.9927
# Epoch 12/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0366 - accuracy: 0.9920 - val_loss: 0.0315 - val_accuracy: 0.9938
# Epoch 13/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0381 - accuracy: 0.9920 - val_loss: 0.0384 - val_accuracy: 0.9926
# Epoch 14/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0383 - accuracy: 0.9919 - val_loss: 0.0240 - val_accuracy: 0.9937
# Epoch 15/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0207 - accuracy: 0.9950 - val_loss: 0.0408 - val_accuracy: 0.9919
# Epoch 16/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0226 - accuracy: 0.9948 - val_loss: 0.0389 - val_accuracy: 0.9914
# Epoch 17/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0245 - accuracy: 0.9948 - val_loss: 0.0659 - val_accuracy: 0.9866
# Epoch 18/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0630 - accuracy: 0.9910 - val_loss: 1.0798 - val_accuracy: 0.8872
# Epoch 19/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0345 - accuracy: 0.9933 - val_loss: 0.0249 - val_accuracy: 0.9941
# Epoch 20/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0184 - accuracy: 0.9961 - val_loss: 0.0492 - val_accuracy: 0.9892
# Epoch 21/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.0293 - val_accuracy: 0.9944
# Epoch 22/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 0.0395 - val_accuracy: 0.9939
# Epoch 23/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0240 - accuracy: 0.9952 - val_loss: 0.0309 - val_accuracy: 0.9930
# Epoch 24/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0131 - accuracy: 0.9969 - val_loss: 0.0355 - val_accuracy: 0.9926
# Epoch 25/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0173 - accuracy: 0.9963 - val_loss: 0.0294 - val_accuracy: 0.9941
# Epoch 26/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0138 - accuracy: 0.9969 - val_loss: 0.0317 - val_accuracy: 0.9936
# Epoch 27/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0218 - accuracy: 0.9955 - val_loss: 0.0414 - val_accuracy: 0.9912
# Epoch 28/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 0.0304 - val_accuracy: 0.9921
# Epoch 29/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0503 - accuracy: 0.9940 - val_loss: 0.0279 - val_accuracy: 0.9953
# Epoch 30/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0492 - accuracy: 0.9926 - val_loss: 0.0294 - val_accuracy: 0.9918
# Epoch 31/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0163 - accuracy: 0.9963 - val_loss: 0.0228 - val_accuracy: 0.9950
# Epoch 32/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.0216 - val_accuracy: 0.9953
# Epoch 33/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0089 - accuracy: 0.9981 - val_loss: 0.0374 - val_accuracy: 0.9952
# Epoch 34/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 0.0428 - val_accuracy: 0.9937
# Epoch 35/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0124 - accuracy: 0.9975 - val_loss: 0.0727 - val_accuracy: 0.9926
# Epoch 36/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0133 - accuracy: 0.9972 - val_loss: 0.0303 - val_accuracy: 0.9943
# Epoch 37/200
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0163 - accuracy: 0.9968 - val_loss: 0.0418 - val_accuracy: 0.9937
# Epoch 38/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.0358 - val_accuracy: 0.9940
# Epoch 39/200
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0276 - accuracy: 0.9962 - val_loss: 0.0949 - val_accuracy: 0.9917
# Epoch 40/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0209 - accuracy: 0.9961 - val_loss: 0.0411 - val_accuracy: 0.9948
# Epoch 41/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0127 - accuracy: 0.9972 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 42/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0322 - val_accuracy: 0.9949
# Epoch 43/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0376 - val_accuracy: 0.9940
# Epoch 44/200
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.0223 - val_accuracy: 0.9958
# Epoch 45/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0320 - val_accuracy: 0.9943
# Epoch 46/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0258 - accuracy: 0.9963 - val_loss: 0.0244 - val_accuracy: 0.9947
# Epoch 47/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0124 - accuracy: 0.9975 - val_loss: 0.0520 - val_accuracy: 0.9941
# Epoch 48/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 0.0276 - val_accuracy: 0.9951
# Epoch 49/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0568 - val_accuracy: 0.9905
# Epoch 50/200
# 938/938 [==============================] - 105s 112ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0251 - val_accuracy: 0.9955
# Epoch 51/200
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.0508 - val_accuracy: 0.9920
# Epoch 52/200
# 938/938 [==============================] - 106s 114ms/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.0261 - val_accuracy: 0.9961
# Epoch 00052: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
_, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 1.000, Test accuracy: 0.996

# %%
predictions = model.predict(x_test.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test_[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.61 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test_[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test_[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [4 2 4 8 4]
# classified as: [2 7 9 2 2]
# True:          [8 6 9 7 5]
# classified as: [9 0 4 1 3]
