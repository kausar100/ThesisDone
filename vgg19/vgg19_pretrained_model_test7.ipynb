# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.models import Model

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
y_test_ = y_test
print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Train Set Size = 60000 images
# Test Set Size = 10000 images
# (60000, 28, 28)
# (10000, 28, 28)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
print(x_train.shape)
print(x_test.shape)

# expand new axis, channel axis 
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# it's always better to normalize 
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255


# resize the input shape , i.e. old shape: 28, new shape: 32
x_train = tf.image.resize(x_train, [32,32]) # if we want to resize 
x_test = tf.image.resize(x_test, [32,32]) # if we want to resize 

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 32, 32, 1)
# (10000, 32, 32, 1)

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = list((map(reshaping,x_train)))
x_train = np.array(a)

b = list((map(reshaping,x_test)))
x_test = np.array(b)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 32, 32)
# (10000, 32, 32)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
from  keras.utils import np_utils
y_train = to_categorical(y_train, num_classes=10, dtype='float32')
y_test = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 60000 images
# Test Set Size = 10000 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def four_conv_pool(x, F1, F2, F3, F4, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F4, (3, 3), activation=None, padding='same', name='{}_conv4'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        net = X_input


        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = four_conv_pool(net, 256, 256, 256, 256, "block3")
        net = four_conv_pool(net, 512, 512, 512, 512, "block4")
        #net = four_conv_pool(net, 512, 512, 512, 512, "block5")


        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)
        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(512, activation='relu', name='fc3')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg19')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model = vggModel()
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        640
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 8, 8, 256)         0
#
#  block3_conv4 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 8, 8, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  fc3 (Dense)                 (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 17,422,282
# Trainable params: 17,415,370
# Non-trainable params: 6,912
# _________________________________________________________________

# %%
batch_size = 64
num_epoch = 200

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = ModelCheckpoint('/content/drive/MyDrive/model/vgg19_model_test7.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

#model training
ret = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,
          #validation_split=0.25,
          validation_data=(x_test, y_test),
          callbacks=[es, mc])
# Out:
# Epoch 1/200
# 938/938 [==============================] - 98s 93ms/step - loss: 0.4874 - accuracy: 0.8392 - val_loss: 0.2149 - val_accuracy: 0.9566
# Epoch 2/200
# 938/938 [==============================] - 87s 93ms/step - loss: 0.1021 - accuracy: 0.9768 - val_loss: 0.0749 - val_accuracy: 0.9839
# Epoch 3/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0859 - accuracy: 0.9805 - val_loss: 0.0894 - val_accuracy: 0.9813
# Epoch 4/200
# 938/938 [==============================] - 86s 91ms/step - loss: 0.0731 - accuracy: 0.9846 - val_loss: 0.1063 - val_accuracy: 0.9754
# Epoch 5/200
# 938/938 [==============================] - 86s 92ms/step - loss: 0.0730 - accuracy: 0.9849 - val_loss: 0.0481 - val_accuracy: 0.9911
# Epoch 6/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0750 - accuracy: 0.9851 - val_loss: 0.0483 - val_accuracy: 0.9901
# Epoch 7/200
# 938/938 [==============================] - 86s 92ms/step - loss: 0.0604 - accuracy: 0.9879 - val_loss: 0.0304 - val_accuracy: 0.9934
# Epoch 8/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0536 - accuracy: 0.9895 - val_loss: 0.0435 - val_accuracy: 0.9916
# Epoch 9/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0544 - accuracy: 0.9894 - val_loss: 0.0397 - val_accuracy: 0.9912
# Epoch 10/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0456 - accuracy: 0.9909 - val_loss: 0.0474 - val_accuracy: 0.9934
# Epoch 11/200
# 938/938 [==============================] - 87s 92ms/step - loss: 0.0488 - accuracy: 0.9906 - val_loss: 0.0359 - val_accuracy: 0.9924
# Epoch 12/200
# 938/938 [==============================] - 86s 91ms/step - loss: 0.0412 - accuracy: 0.9916 - val_loss: 0.0442 - val_accuracy: 0.9920
# Epoch 13/200
# 938/938 [==============================] - 87s 93ms/step - loss: 0.0431 - accuracy: 0.9912 - val_loss: 0.0275 - val_accuracy: 0.9947
# Epoch 14/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0402 - accuracy: 0.9927 - val_loss: 0.0481 - val_accuracy: 0.9907
# Epoch 15/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0487 - accuracy: 0.9910 - val_loss: 0.0268 - val_accuracy: 0.9947
# Epoch 16/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0318 - accuracy: 0.9936 - val_loss: 0.0332 - val_accuracy: 0.9927
# Epoch 17/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0411 - accuracy: 0.9919 - val_loss: 0.0419 - val_accuracy: 0.9935
# Epoch 18/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0296 - accuracy: 0.9937 - val_loss: 0.0290 - val_accuracy: 0.9945
# Epoch 19/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0246 - accuracy: 0.9949 - val_loss: 0.0227 - val_accuracy: 0.9943
# Epoch 20/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0183 - accuracy: 0.9956 - val_loss: 0.0340 - val_accuracy: 0.9946
# Epoch 21/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0409 - accuracy: 0.9929 - val_loss: 0.5466 - val_accuracy: 0.9714
# Epoch 22/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0523 - accuracy: 0.9909 - val_loss: 0.0363 - val_accuracy: 0.9926
# Epoch 23/200
# 938/938 [==============================] - 86s 92ms/step - loss: 0.0215 - accuracy: 0.9952 - val_loss: 0.0228 - val_accuracy: 0.9951
# Epoch 24/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0178 - accuracy: 0.9959 - val_loss: 0.0331 - val_accuracy: 0.9928
# Epoch 25/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0173 - accuracy: 0.9963 - val_loss: 0.0315 - val_accuracy: 0.9920
# Epoch 26/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 0.0268 - val_accuracy: 0.9937
# Epoch 27/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0155 - accuracy: 0.9967 - val_loss: 0.0978 - val_accuracy: 0.9907
# Epoch 28/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0208 - accuracy: 0.9956 - val_loss: 0.0380 - val_accuracy: 0.9948
# Epoch 29/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0381 - accuracy: 0.9930 - val_loss: 0.0449 - val_accuracy: 0.9932
# Epoch 30/200
# 938/938 [==============================] - 85s 91ms/step - loss: 0.0390 - accuracy: 0.9948 - val_loss: 0.0318 - val_accuracy: 0.9948
# Epoch 31/200
# 938/938 [==============================] - 87s 92ms/step - loss: 0.0286 - accuracy: 0.9952 - val_loss: 0.0232 - val_accuracy: 0.9955
# Epoch 32/200
# 938/938 [==============================] - 85s 90ms/step - loss: 0.0160 - accuracy: 0.9965 - val_loss: 0.0498 - val_accuracy: 0.9945
# Epoch 33/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0418 - val_accuracy: 0.9951
# Epoch 34/200
# 938/938 [==============================] - 85s 90ms/step - loss: 0.0180 - accuracy: 0.9963 - val_loss: 0.0421 - val_accuracy: 0.9942
# Epoch 35/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.0604 - val_accuracy: 0.9955
# Epoch 36/200
# 938/938 [==============================] - 85s 90ms/step - loss: 0.0183 - accuracy: 0.9962 - val_loss: 0.0465 - val_accuracy: 0.9940
# Epoch 37/200
# 938/938 [==============================] - 85s 90ms/step - loss: 0.0163 - accuracy: 0.9965 - val_loss: 0.0703 - val_accuracy: 0.9908
# Epoch 38/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0217 - accuracy: 0.9956 - val_loss: 0.0277 - val_accuracy: 0.9942
# Epoch 39/200
# 938/938 [==============================] - 84s 90ms/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 0.0422 - val_accuracy: 0.9939
# Epoch 00039: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
_, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.998, Test accuracy: 0.994

# %%
predictions = model.predict(x_test.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test_[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.39 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test_[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test_[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [9 9 6 3 2]
# classified as: [4 4 0 5 1]
# True:          [8 6 7 9 7]
# classified as: [9 0 1 4 1]
