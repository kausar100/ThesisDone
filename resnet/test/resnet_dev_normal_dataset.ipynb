# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.initializers import glorot_uniform
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/dev dataset/train_data.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/dev dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[0]
#  [7]
#  [4]
#  [9]
#  [1]]
# Labels : [[7]
#  [2]
#  [0]
#  [8]
#  [7]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (18000, 32, 32)
# (3750, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 18000 images
# Test Set Size = 3750 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def identity_block(X, f, filters, stage, block):
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1,1), strides=(1,1), padding='valid', name=conv_name_base+'2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f,f), strides=(1,1), padding='same', name=conv_name_base+'2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), padding='valid', name=conv_name_base+'2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2c')(X)

    X = layers.Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

def convolutional_block(X, f, filters, stage, block, s=2):
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1,1), strides=(s,s), name=conv_name_base+'2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f,f), strides=(1,1), padding='same', name=conv_name_base+'2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), name=conv_name_base+'2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2c')(X)

    X_shortcut = Conv2D(F3, kernel_size=(1,1), strides=(s,s), name=conv_name_base+'1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base+'1')(X_shortcut)

    X = layers.Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X


def resNet():
    
    # Define the input as a tensor with shape input_shape
    X_input = Input((32,32,1))
    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1',)(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    
    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')
    
    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    '''
    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')
    
    '''

    # AVGPOOL
    X = AveragePooling2D((2,2), name='avg_pool')(X)
    
    # output layer
    X = Dropout(rate=.2)(X)
    X = Flatten()(X)
    X = Dropout(rate=.5)(X)

    X = Dense(2048, activation='relu', name='fc1')(X)
    X = Dropout(rate=.2)(X)
    X = Dense(1024, activation='relu', name='fc2')(X)
    X = Dropout(rate=.2)(X)

    X = Dense(y_train_.shape[1], activation='softmax', name='predictions' + str(y_train_.shape[1]))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')
    
    #Compile the model
    model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
    return model

# %%
model_n = resNet()
model_n.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 1)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 38, 38, 1)   0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   3200        ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 7, 7, 64)     0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 7, 7, 64)     4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 7, 7, 64)    256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 7, 7, 64)     0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 7, 7, 64)     36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 7, 7, 64)    256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 7, 7, 64)     0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 7, 7, 256)    16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 7, 7, 256)    16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 7, 7, 256)   1024        ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 7, 7, 256)   1024        ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 7, 7, 256)    0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 256)    0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 7, 7, 64)     16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 7, 7, 64)    256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 7, 7, 64)     0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 7, 7, 64)     36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 7, 7, 64)    256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 7, 7, 64)     0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 7, 7, 256)    16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 7, 7, 256)   1024        ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 7, 7, 256)    0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 7, 7, 256)    0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 7, 7, 64)     16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 7, 7, 64)    256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 7, 7, 64)     0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 7, 7, 64)     36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 7, 7, 64)    256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 7, 7, 64)     0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 7, 7, 256)    16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 7, 7, 256)   1024        ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 7, 7, 256)    0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 7, 7, 256)    0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 4, 4, 128)    32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 4, 4, 128)    147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 4, 4, 512)    66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 4, 4, 512)    131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 4, 4, 512)   2048        ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 512)   2048        ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 4, 4, 512)    0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 512)    0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 4, 4, 128)    65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 4, 4, 512)    66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 4, 4, 512)   2048        ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 4, 4, 512)    0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 4, 4, 512)    0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 4, 4, 128)    65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 4, 4, 128)    147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 4, 4, 512)    66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 4, 4, 512)   2048        ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 4, 4, 512)    0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 4, 4, 512)    0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 4, 4, 128)    65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 4, 4, 128)    147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 4, 4, 512)    66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 4, 4, 512)   2048        ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 4, 4, 512)    0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 4, 4, 512)    0           ['add_6[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 2, 2, 512)    0           ['activation_21[0][0]']
#
#  dropout (Dropout)              (None, 2, 2, 512)    0           ['avg_pool[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 2048)         0           ['flatten[0][0]']
#
#  fc1 (Dense)                    (None, 2048)         4196352     ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['fc1[0][0]']
#
#  fc2 (Dense)                    (None, 1024)         2098176     ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['fc2[0][0]']
#
#  predictions10 (Dense)          (None, 10)           10250       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 7,758,602
# Trainable params: 7,748,490
# Non-trainable params: 10,112
# __________________________________________________________________________________________________

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 282/282 [==============================] - 25s 58ms/step - loss: 0.9857 - accuracy: 0.7425 - val_loss: 2.0508 - val_accuracy: 0.4067
# Epoch 2/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0826 - accuracy: 0.9759 - val_loss: 0.1348 - val_accuracy: 0.9667
# Epoch 3/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0521 - accuracy: 0.9849 - val_loss: 0.1117 - val_accuracy: 0.9709
# Epoch 4/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0381 - accuracy: 0.9898 - val_loss: 0.0572 - val_accuracy: 0.9864
# Epoch 5/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0387 - accuracy: 0.9905 - val_loss: 0.1514 - val_accuracy: 0.9653
# Epoch 6/100
# 282/282 [==============================] - 15s 53ms/step - loss: 0.0386 - accuracy: 0.9902 - val_loss: 0.0921 - val_accuracy: 0.9800
# Epoch 7/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0261 - accuracy: 0.9936 - val_loss: 0.1140 - val_accuracy: 0.9765
# Epoch 8/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0269 - accuracy: 0.9933 - val_loss: 0.0753 - val_accuracy: 0.9867
# Epoch 9/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0352 - accuracy: 0.9912 - val_loss: 0.1067 - val_accuracy: 0.9795
# Epoch 10/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0441 - accuracy: 0.9896 - val_loss: 0.1601 - val_accuracy: 0.9677
# Epoch 11/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0313 - accuracy: 0.9927 - val_loss: 0.1696 - val_accuracy: 0.9715
# Epoch 12/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0259 - accuracy: 0.9944 - val_loss: 0.0543 - val_accuracy: 0.9901
# Epoch 13/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0211 - accuracy: 0.9949 - val_loss: 0.1498 - val_accuracy: 0.9763
# Epoch 14/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0209 - accuracy: 0.9944 - val_loss: 0.0563 - val_accuracy: 0.9917
# Epoch 15/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0390 - accuracy: 0.9918 - val_loss: 0.0732 - val_accuracy: 0.9856
# Epoch 16/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0200 - accuracy: 0.9950 - val_loss: 0.1633 - val_accuracy: 0.9741
# Epoch 17/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0229 - accuracy: 0.9949 - val_loss: 0.0729 - val_accuracy: 0.9859
# Epoch 18/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0273 - accuracy: 0.9939 - val_loss: 0.0667 - val_accuracy: 0.9891
# Epoch 19/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0190 - accuracy: 0.9951 - val_loss: 0.2213 - val_accuracy: 0.9717
# Epoch 20/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0181 - accuracy: 0.9958 - val_loss: 0.1398 - val_accuracy: 0.9717
# Epoch 21/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0352 - accuracy: 0.9924 - val_loss: 0.0933 - val_accuracy: 0.9872
# Epoch 22/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0178 - accuracy: 0.9957 - val_loss: 0.0990 - val_accuracy: 0.9859
# Epoch 23/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0339 - accuracy: 0.9932 - val_loss: 0.2100 - val_accuracy: 0.9757
# Epoch 24/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0248 - accuracy: 0.9953 - val_loss: 0.0540 - val_accuracy: 0.9899
# Epoch 25/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.0640 - val_accuracy: 0.9901
# Epoch 26/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0144 - accuracy: 0.9977 - val_loss: 0.2560 - val_accuracy: 0.9667
# Epoch 27/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0273 - accuracy: 0.9948 - val_loss: 0.2776 - val_accuracy: 0.9637
# Epoch 28/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0230 - accuracy: 0.9948 - val_loss: 0.0589 - val_accuracy: 0.9912
# Epoch 29/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0197 - accuracy: 0.9959 - val_loss: 0.0520 - val_accuracy: 0.9869
# Epoch 30/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 0.0357 - val_accuracy: 0.9941
# Epoch 31/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.0704 - val_accuracy: 0.9883
# Epoch 32/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.0486 - val_accuracy: 0.9928
# Epoch 33/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0133 - accuracy: 0.9977 - val_loss: 0.4009 - val_accuracy: 0.9533
# Epoch 34/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0586 - accuracy: 0.9913 - val_loss: 0.2490 - val_accuracy: 0.9741
# Epoch 35/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0187 - accuracy: 0.9955 - val_loss: 0.0822 - val_accuracy: 0.9867
# Epoch 36/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0285 - accuracy: 0.9957 - val_loss: 0.0834 - val_accuracy: 0.9912
# Epoch 37/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.0757 - val_accuracy: 0.9904
# Epoch 38/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0885 - val_accuracy: 0.9869
# Epoch 39/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0156 - accuracy: 0.9970 - val_loss: 0.0605 - val_accuracy: 0.9915
# Epoch 40/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0071 - accuracy: 0.9988 - val_loss: 0.2578 - val_accuracy: 0.9760
# Epoch 41/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0331 - accuracy: 0.9948 - val_loss: 0.0619 - val_accuracy: 0.9904
# Epoch 42/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.0547 - val_accuracy: 0.9917
# Epoch 43/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0519 - val_accuracy: 0.9928
# Epoch 44/100
# 282/282 [==============================] - 14s 51ms/step - loss: 0.0131 - accuracy: 0.9980 - val_loss: 0.0700 - val_accuracy: 0.9928
# Epoch 45/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0125 - accuracy: 0.9986 - val_loss: 0.1664 - val_accuracy: 0.9795
# Epoch 46/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0190 - accuracy: 0.9968 - val_loss: 0.0776 - val_accuracy: 0.9872
# Epoch 47/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0385 - val_accuracy: 0.9952
# Epoch 48/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0093 - accuracy: 0.9982 - val_loss: 0.0788 - val_accuracy: 0.9912
# Epoch 49/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0106 - accuracy: 0.9983 - val_loss: 0.1053 - val_accuracy: 0.9899
# Epoch 50/100
# 282/282 [==============================] - 14s 49ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0519 - val_accuracy: 0.9936
# Epoch 00050: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 1.000, Test accuracy: 0.994

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.36 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[5]
#  [6]
#  [2]
#  [6]
#  [5]]
# classified as: [4 9 1 1 1]
# True:          [[1]
#  [1]
#  [9]
#  [1]
#  [5]]
# classified as: [5 8 2 5 4]
