# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.models import Model

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
y_test_ = y_test
print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Train Set Size = 60000 images
# Test Set Size = 10000 images
# (60000, 28, 28)
# (10000, 28, 28)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
print(x_train.shape)
print(x_test.shape)

# expand new axis, channel axis 
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# it's always better to normalize 
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255


# resize the input shape , i.e. old shape: 28, new shape: 32
x_train = tf.image.resize(x_train, [32,32]) # if we want to resize 
x_test = tf.image.resize(x_test, [32,32]) # if we want to resize 

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 32, 32, 1)
# (10000, 32, 32, 1)

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = list((map(reshaping,x_train)))
x_train = np.array(a)

b = list((map(reshaping,x_test)))
x_test = np.array(b)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 32, 32)
# (10000, 32, 32)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
from  keras.utils import np_utils
y_train = to_categorical(y_train, num_classes=10, dtype='float32')
y_test = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 60000 images
# Test Set Size = 10000 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def three_conv_pool(x, F1, F2, F3, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        
        # Zero-Padding
        net = ZeroPadding2D((3, 3))(X_input)

        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = three_conv_pool(net, 256, 256, 256, "block3")
        net = three_conv_pool(net, 512, 512, 512, "block4")
        #net = three_conv_pool(net, 512, 512, 512, "block5")

        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)

        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg16')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model = vggModel()
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_7 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 13,949,642
# Trainable params: 13,944,266
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
batch_size = 64
num_epoch = 200

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = ModelCheckpoint('/content/drive/MyDrive/model/vgg16_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

#model training
ret = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,
          #validation_split=0.25,
          validation_data=(x_test, y_test),
          callbacks=[es, mc])
# Out:
# Epoch 1/200
# 938/938 [==============================] - 134s 131ms/step - loss: 0.3857 - accuracy: 0.8877 - val_loss: 0.4459 - val_accuracy: 0.9037
# Epoch 2/200
# 938/938 [==============================] - 121s 130ms/step - loss: 0.0828 - accuracy: 0.9788 - val_loss: 0.0746 - val_accuracy: 0.9783
# Epoch 3/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0641 - accuracy: 0.9842 - val_loss: 0.1515 - val_accuracy: 0.9640
# Epoch 4/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0607 - accuracy: 0.9850 - val_loss: 0.0648 - val_accuracy: 0.9850
# Epoch 5/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0535 - accuracy: 0.9869 - val_loss: 0.1107 - val_accuracy: 0.9747
# Epoch 6/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0529 - accuracy: 0.9874 - val_loss: 0.2559 - val_accuracy: 0.9573
# Epoch 7/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0552 - accuracy: 0.9881 - val_loss: 0.0424 - val_accuracy: 0.9900
# Epoch 8/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0450 - accuracy: 0.9904 - val_loss: 0.1249 - val_accuracy: 0.9723
# Epoch 9/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0390 - accuracy: 0.9912 - val_loss: 0.0570 - val_accuracy: 0.9869
# Epoch 10/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0355 - accuracy: 0.9923 - val_loss: 0.0419 - val_accuracy: 0.9921
# Epoch 11/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0356 - accuracy: 0.9923 - val_loss: 0.0679 - val_accuracy: 0.9866
# Epoch 12/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0295 - accuracy: 0.9937 - val_loss: 0.0344 - val_accuracy: 0.9928
# Epoch 13/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0322 - accuracy: 0.9928 - val_loss: 0.0444 - val_accuracy: 0.9919
# Epoch 14/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0260 - accuracy: 0.9940 - val_loss: 0.0406 - val_accuracy: 0.9939
# Epoch 15/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0263 - accuracy: 0.9947 - val_loss: 0.0416 - val_accuracy: 0.9950
# Epoch 16/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0252 - accuracy: 0.9944 - val_loss: 0.0313 - val_accuracy: 0.9944
# Epoch 17/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0234 - accuracy: 0.9948 - val_loss: 0.0393 - val_accuracy: 0.9932
# Epoch 18/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0281 - accuracy: 0.9944 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 19/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0226 - accuracy: 0.9957 - val_loss: 0.0492 - val_accuracy: 0.9923
# Epoch 20/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0272 - accuracy: 0.9949 - val_loss: 0.0373 - val_accuracy: 0.9936
# Epoch 21/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0184 - accuracy: 0.9959 - val_loss: 0.0280 - val_accuracy: 0.9956
# Epoch 22/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.0337 - val_accuracy: 0.9948
# Epoch 23/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0190 - accuracy: 0.9962 - val_loss: 0.0381 - val_accuracy: 0.9946
# Epoch 24/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0239 - accuracy: 0.9956 - val_loss: 0.0428 - val_accuracy: 0.9918
# Epoch 25/200
# 938/938 [==============================] - 121s 129ms/step - loss: 0.0164 - accuracy: 0.9965 - val_loss: 0.0239 - val_accuracy: 0.9963
# Epoch 26/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0117 - accuracy: 0.9974 - val_loss: 0.0402 - val_accuracy: 0.9938
# Epoch 27/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0124 - accuracy: 0.9975 - val_loss: 0.0434 - val_accuracy: 0.9944
# Epoch 28/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0227 - accuracy: 0.9957 - val_loss: 0.0296 - val_accuracy: 0.9933
# Epoch 29/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0115 - accuracy: 0.9976 - val_loss: 0.0247 - val_accuracy: 0.9947
# Epoch 30/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.0346 - val_accuracy: 0.9945
# Epoch 31/200
# 938/938 [==============================] - 123s 132ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.0304 - val_accuracy: 0.9954
# Epoch 32/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0261 - val_accuracy: 0.9954
# Epoch 33/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0156 - accuracy: 0.9970 - val_loss: 0.0400 - val_accuracy: 0.9941
# Epoch 34/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0235 - accuracy: 0.9969 - val_loss: 0.0357 - val_accuracy: 0.9941
# Epoch 35/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.0334 - val_accuracy: 0.9949
# Epoch 36/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0100 - accuracy: 0.9981 - val_loss: 0.0392 - val_accuracy: 0.9944
# Epoch 37/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0486 - val_accuracy: 0.9938
# Epoch 38/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0491 - accuracy: 0.9956 - val_loss: 0.0433 - val_accuracy: 0.9954
# Epoch 39/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0621 - val_accuracy: 0.9941
# Epoch 40/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.0488 - val_accuracy: 0.9940
# Epoch 41/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0358 - val_accuracy: 0.9952
# Epoch 42/200
# 938/938 [==============================] - 124s 132ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0345 - val_accuracy: 0.9958
# Epoch 43/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0133 - accuracy: 0.9975 - val_loss: 0.2440 - val_accuracy: 0.9817
# Epoch 44/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0125 - accuracy: 0.9979 - val_loss: 0.0347 - val_accuracy: 0.9940
# Epoch 45/200
# 938/938 [==============================] - 119s 127ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0322 - val_accuracy: 0.9957
# Epoch 00045: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
_, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.999, Test accuracy: 0.996

# %%
predictions = model.predict(x_test.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test_[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.57 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test_[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test_[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [3 4 4 6 3]
# classified as: [5 9 2 0 5]
# True:          [3 8 6 7 9]
# classified as: [5 9 8 2 4]
