# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/dev dataset/train_data.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/dev dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[0]
#  [7]
#  [4]
#  [9]
#  [1]]
# Labels : [[7]
#  [2]
#  [0]
#  [8]
#  [7]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (18000, 32, 32)
# (3750, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 18000 images
# Test Set Size = 3750 images

# %%
# load model
from keras import models    
model_new = models.load_model('/content/drive/MyDrive/model/vgg16_model_test6.h5')
#set trainable false for pretrained model
for layer in model_new.layers[:-10]:
    layer.trainable = False

for l in model_new.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 False
# batch_normalization_10 False
# activation_10 False
# block1_conv2 False
# batch_normalization_11 False
# activation_11 False
# block1_pool False
# block2_conv1 False
# batch_normalization_12 False
# activation_12 False
# block2_conv2 False
# batch_normalization_13 False
# activation_13 False
# block2_pool False
# block3_conv1 False
# batch_normalization_14 False
# activation_14 False
# block3_conv2 False
# batch_normalization_15 False
# activation_15 False
# block3_conv3 False
# batch_normalization_16 False
# activation_16 False
# block3_pool False
# block4_conv1 False
# batch_normalization_17 False
# activation_17 False
# block4_conv2 False
# batch_normalization_18 False
# activation_18 False
# block4_conv3 False
# batch_normalization_19 False
# activation_19 False
# block4_pool False
# dropout_4 True
# flatten_1 True
# dropout_5 True
# fc1 True
# dropout_6 True
# fc2 True
# dropout_7 True
# fc3 True
# dropout_8 True
# predictions True

# %%
model_new.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        640
#
#  batch_normalization_10 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_16 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_17 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_17 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_18 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_18 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_19 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_19 (Activation)  (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout_4 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout_5 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_6 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  fc3 (Dense)                 (None, 512)               524800
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 14,469,322
# Trainable params: 6,824,458
# Non-trainable params: 7,644,864
# _________________________________________________________________

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

#extract layer weight
last_layer = model_new.get_layer('block3_pool')
last_output = last_layer.output

net = Dropout(rate=.2)(last_output)
net = Flatten()(net)
net = Dropout(rate=.5)(net)
net = Dense(2048, activation='relu', name='fc')(net)
net = Dropout(rate=.2)(net)
net = Dense(1024, activation='relu', name='fc2')(net)
net = Dropout(rate=.2)(net)
net = Dense(512, activation='relu', name='fc3')(net)
net = Dropout(rate=.2)(net)
net = Dense(10, activation='softmax', name='predictions_utl')(net)

# Create model
model_n = Model(inputs = model_new.input, outputs = net, name='vgg16_utl')
model_n.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])

model_n.summary()
# Out:
# Model: "vgg16_utl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        640
#
#  batch_normalization_10 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_16 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  dropout_15 (Dropout)        (None, 4, 4, 256)         0
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dropout_16 (Dropout)        (None, 4096)              0
#
#  fc (Dense)                  (None, 2048)              8390656
#
#  dropout_17 (Dropout)        (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_18 (Dropout)        (None, 1024)              0
#
#  fc3 (Dense)                 (None, 512)               524800
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  predictions_utl (Dense)     (None, 10)                5130
#
# =================================================================
# Total params: 12,757,706
# Trainable params: 11,018,762
# Non-trainable params: 1,738,944
# _________________________________________________________________

# %%
for l in model_n.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 False
# batch_normalization_10 False
# activation_10 False
# block1_conv2 False
# batch_normalization_11 False
# activation_11 False
# block1_pool False
# block2_conv1 False
# batch_normalization_12 False
# activation_12 False
# block2_conv2 False
# batch_normalization_13 False
# activation_13 False
# block2_pool False
# block3_conv1 False
# batch_normalization_14 False
# activation_14 False
# block3_conv2 False
# batch_normalization_15 False
# activation_15 False
# block3_conv3 False
# batch_normalization_16 False
# activation_16 False
# block3_pool False
# dropout_15 True
# flatten_3 True
# dropout_16 True
# fc True
# dropout_17 True
# fc2 True
# dropout_18 True
# fc3 True
# dropout_19 True
# predictions_utl True

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 282/282 [==============================] - 10s 29ms/step - loss: 0.2503 - accuracy: 0.9301 - val_loss: 0.0988 - val_accuracy: 0.9693
# Epoch 2/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0801 - accuracy: 0.9761 - val_loss: 0.0806 - val_accuracy: 0.9792
# Epoch 3/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0685 - accuracy: 0.9806 - val_loss: 0.0702 - val_accuracy: 0.9784
# Epoch 4/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0595 - accuracy: 0.9845 - val_loss: 0.0555 - val_accuracy: 0.9837
# Epoch 5/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0379 - accuracy: 0.9900 - val_loss: 0.0471 - val_accuracy: 0.9877
# Epoch 6/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0435 - accuracy: 0.9880 - val_loss: 0.0451 - val_accuracy: 0.9877
# Epoch 7/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0368 - accuracy: 0.9904 - val_loss: 0.0666 - val_accuracy: 0.9851
# Epoch 8/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0410 - accuracy: 0.9909 - val_loss: 0.0567 - val_accuracy: 0.9859
# Epoch 9/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0317 - accuracy: 0.9918 - val_loss: 0.0477 - val_accuracy: 0.9872
# Epoch 10/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0338 - accuracy: 0.9916 - val_loss: 0.0391 - val_accuracy: 0.9907
# Epoch 11/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0344 - accuracy: 0.9918 - val_loss: 0.0483 - val_accuracy: 0.9869
# Epoch 12/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0274 - accuracy: 0.9931 - val_loss: 0.0366 - val_accuracy: 0.9915
# Epoch 13/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0292 - accuracy: 0.9932 - val_loss: 0.0555 - val_accuracy: 0.9885
# Epoch 14/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0324 - accuracy: 0.9921 - val_loss: 0.0323 - val_accuracy: 0.9928
# Epoch 15/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0358 - accuracy: 0.9924 - val_loss: 0.0351 - val_accuracy: 0.9923
# Epoch 16/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0267 - accuracy: 0.9938 - val_loss: 0.0630 - val_accuracy: 0.9864
# Epoch 17/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0296 - accuracy: 0.9926 - val_loss: 0.0599 - val_accuracy: 0.9901
# Epoch 18/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0221 - accuracy: 0.9949 - val_loss: 0.0653 - val_accuracy: 0.9896
# Epoch 19/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0277 - accuracy: 0.9935 - val_loss: 0.0994 - val_accuracy: 0.9888
# Epoch 20/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0393 - accuracy: 0.9927 - val_loss: 0.1003 - val_accuracy: 0.9869
# Epoch 21/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0358 - accuracy: 0.9928 - val_loss: 0.0534 - val_accuracy: 0.9920
# Epoch 22/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0262 - accuracy: 0.9944 - val_loss: 0.0446 - val_accuracy: 0.9912
# Epoch 23/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0363 - accuracy: 0.9927 - val_loss: 0.0423 - val_accuracy: 0.9939
# Epoch 24/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0269 - accuracy: 0.9944 - val_loss: 0.0241 - val_accuracy: 0.9949
# Epoch 25/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0234 - accuracy: 0.9953 - val_loss: 0.0426 - val_accuracy: 0.9923
# Epoch 26/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0199 - accuracy: 0.9953 - val_loss: 0.0540 - val_accuracy: 0.9917
# Epoch 27/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0221 - accuracy: 0.9954 - val_loss: 0.0765 - val_accuracy: 0.9904
# Epoch 28/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0206 - accuracy: 0.9956 - val_loss: 0.0694 - val_accuracy: 0.9920
# Epoch 29/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0274 - accuracy: 0.9949 - val_loss: 0.0921 - val_accuracy: 0.9896
# Epoch 30/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0223 - accuracy: 0.9956 - val_loss: 0.0694 - val_accuracy: 0.9899
# Epoch 31/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0232 - accuracy: 0.9954 - val_loss: 0.0550 - val_accuracy: 0.9915
# Epoch 32/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0321 - accuracy: 0.9948 - val_loss: 0.0546 - val_accuracy: 0.9923
# Epoch 33/100
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0193 - accuracy: 0.9971 - val_loss: 0.0460 - val_accuracy: 0.9928
# Epoch 34/100
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0233 - accuracy: 0.9958 - val_loss: 0.0799 - val_accuracy: 0.9899
# Epoch 00034: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.999, Test accuracy: 0.990

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 98.98666666666666 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[1]
#  [5]
#  [6]
#  [3]
#  [6]]
# classified as: [7 4 9 2 9]
# True:          [[1]
#  [1]
#  [2]
#  [5]
#  [9]]
# classified as: [9 2 8 4 2]
