# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.initializers import glorot_uniform
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/dev dataset/train_data.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/dev dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[0]
#  [7]
#  [4]
#  [9]
#  [1]]
# Labels : [[7]
#  [2]
#  [0]
#  [8]
#  [7]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (18000, 32, 32)
# (3750, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 18000 images
# Test Set Size = 3750 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def three_conv_pool(x, F1, F2, F3, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        
        # Zero-Padding
        net = ZeroPadding2D((3, 3))(X_input)

        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = three_conv_pool(net, 256, 256, 256, "block3")
        net = three_conv_pool(net, 512, 512, 512, "block4")
        #net = three_conv_pool(net, 512, 512, 512, "block5")

        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)

        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg16')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model_n = vggModel()
model_n.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_7 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 13,949,642
# Trainable params: 13,944,266
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 282/282 [==============================] - 45s 132ms/step - loss: 1.1474 - accuracy: 0.6227 - val_loss: 1.4825 - val_accuracy: 0.5589
# Epoch 2/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0905 - accuracy: 0.9753 - val_loss: 0.1852 - val_accuracy: 0.9485
# Epoch 3/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0508 - accuracy: 0.9858 - val_loss: 0.0882 - val_accuracy: 0.9760
# Epoch 4/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0410 - accuracy: 0.9888 - val_loss: 0.0827 - val_accuracy: 0.9813
# Epoch 5/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0343 - accuracy: 0.9906 - val_loss: 0.0835 - val_accuracy: 0.9837
# Epoch 6/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0332 - accuracy: 0.9911 - val_loss: 0.0728 - val_accuracy: 0.9816
# Epoch 7/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0235 - accuracy: 0.9947 - val_loss: 0.1184 - val_accuracy: 0.9744
# Epoch 8/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0363 - accuracy: 0.9916 - val_loss: 0.0937 - val_accuracy: 0.9821
# Epoch 9/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0302 - accuracy: 0.9934 - val_loss: 0.1161 - val_accuracy: 0.9744
# Epoch 10/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0206 - accuracy: 0.9952 - val_loss: 0.0293 - val_accuracy: 0.9952
# Epoch 11/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.0661 - val_accuracy: 0.9872
# Epoch 12/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0252 - accuracy: 0.9953 - val_loss: 0.2400 - val_accuracy: 0.9632
# Epoch 13/100
# 282/282 [==============================] - 36s 126ms/step - loss: 0.0280 - accuracy: 0.9940 - val_loss: 0.0336 - val_accuracy: 0.9917
# Epoch 14/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0224 - accuracy: 0.9959 - val_loss: 0.0801 - val_accuracy: 0.9861
# Epoch 15/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0241 - accuracy: 0.9950 - val_loss: 0.1722 - val_accuracy: 0.9707
# Epoch 16/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.0614 - val_accuracy: 0.9896
# Epoch 17/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0237 - accuracy: 0.9947 - val_loss: 0.0429 - val_accuracy: 0.9928
# Epoch 18/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0580 - val_accuracy: 0.9875
# Epoch 19/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0381 - accuracy: 0.9926 - val_loss: 0.3140 - val_accuracy: 0.9475
# Epoch 20/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0170 - accuracy: 0.9958 - val_loss: 0.0632 - val_accuracy: 0.9888
# Epoch 21/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0128 - accuracy: 0.9973 - val_loss: 0.1408 - val_accuracy: 0.9803
# Epoch 22/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 0.0572 - val_accuracy: 0.9891
# Epoch 23/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0230 - accuracy: 0.9963 - val_loss: 0.0940 - val_accuracy: 0.9829
# Epoch 24/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0222 - accuracy: 0.9960 - val_loss: 0.1687 - val_accuracy: 0.9757
# Epoch 25/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0283 - accuracy: 0.9967 - val_loss: 0.0674 - val_accuracy: 0.9883
# Epoch 26/100
# 282/282 [==============================] - 36s 128ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.0783 - val_accuracy: 0.9888
# Epoch 27/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0116 - accuracy: 0.9979 - val_loss: 0.0582 - val_accuracy: 0.9912
# Epoch 28/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0278 - accuracy: 0.9943 - val_loss: 0.0433 - val_accuracy: 0.9928
# Epoch 29/100
# 282/282 [==============================] - 36s 128ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.1331 - val_accuracy: 0.9837
# Epoch 30/100
# 282/282 [==============================] - 36s 127ms/step - loss: 0.0241 - accuracy: 0.9962 - val_loss: 0.0641 - val_accuracy: 0.9941
# Epoch 00030: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 1.000, Test accuracy: 0.994

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.41333333333333 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[1]
#  [4]
#  [6]
#  [1]
#  [6]]
# classified as: [0 2 9 7 2]
# True:          [[1]
#  [9]
#  [1]
#  [3]
#  [1]]
# classified as: [5 2 5 6 2]
