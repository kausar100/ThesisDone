# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.initializers import glorot_uniform
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/cvpr dataset/train_data.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/cvpr dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[1]
#  [1]
#  [5]
#  [6]
#  [7]]
# Labels : [[3]
#  [9]
#  [8]
#  [2]
#  [3]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (18000, 32, 32)
# (4000, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 18000 images
# Test Set Size = 4000 images

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

def two_conv_pool(x, F1, F2, name):
    x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

    return x

def three_conv_pool(x, F1, F2, F3, name):
        x = Conv2D(F1, (3, 3), activation=None, padding='same', name='{}_conv1'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F2, (3, 3), activation=None, padding='same', name='{}_conv2'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(F3, (3, 3), activation=None, padding='same', name='{}_conv3'.format(name))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2), strides=(2, 2), name='{}_pool'.format(name))(x)

        return x

def vggModel():
        # Define the input as a tensor with shape input_shape
        X_input = Input((32,32,1))
        
        # Zero-Padding
        net = ZeroPadding2D((3, 3))(X_input)

        net = two_conv_pool(net, 64, 64, "block1")
        net = two_conv_pool(net, 128, 128, "block2")
        net = three_conv_pool(net, 256, 256, 256, "block3")
        net = three_conv_pool(net, 512, 512, 512, "block4")
        #net = three_conv_pool(net, 512, 512, 512, "block5")

        net = Dropout(rate=.2)(net)
        net = Flatten()(net)
        net = Dropout(rate=.5)(net)

        net = Dense(2048, activation='relu', name='fc1')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(1024, activation='relu', name='fc2')(net)
        net = Dropout(rate=.2)(net)
        net = Dense(10, activation='softmax', name='predictions')(net)

        # Create model
        model = Model(inputs = X_input, outputs = net, name='vgg16')
        model.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])
    
        return model

# %%
model_n = vggModel()
model_n.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_7 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 13,949,642
# Trainable params: 13,944,266
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 282/282 [==============================] - 52s 135ms/step - loss: 1.1564 - accuracy: 0.6104 - val_loss: 2.4256 - val_accuracy: 0.4457
# Epoch 2/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.1116 - accuracy: 0.9676 - val_loss: 0.1706 - val_accuracy: 0.9557
# Epoch 3/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0755 - accuracy: 0.9791 - val_loss: 0.0908 - val_accuracy: 0.9697
# Epoch 4/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0464 - accuracy: 0.9874 - val_loss: 0.0828 - val_accuracy: 0.9790
# Epoch 5/100
# 282/282 [==============================] - 37s 131ms/step - loss: 0.0510 - accuracy: 0.9863 - val_loss: 0.0570 - val_accuracy: 0.9830
# Epoch 6/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0368 - accuracy: 0.9905 - val_loss: 0.0579 - val_accuracy: 0.9858
# Epoch 7/100
# 282/282 [==============================] - 37s 132ms/step - loss: 0.0402 - accuracy: 0.9907 - val_loss: 0.0702 - val_accuracy: 0.9822
# Epoch 8/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0258 - accuracy: 0.9924 - val_loss: 0.0777 - val_accuracy: 0.9825
# Epoch 9/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0371 - accuracy: 0.9912 - val_loss: 0.0789 - val_accuracy: 0.9810
# Epoch 10/100
# 282/282 [==============================] - 37s 131ms/step - loss: 0.0380 - accuracy: 0.9913 - val_loss: 0.1286 - val_accuracy: 0.9745
# Epoch 11/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0275 - accuracy: 0.9933 - val_loss: 0.1438 - val_accuracy: 0.9630
# Epoch 12/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0387 - accuracy: 0.9903 - val_loss: 0.0477 - val_accuracy: 0.9890
# Epoch 13/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0225 - accuracy: 0.9953 - val_loss: 0.0558 - val_accuracy: 0.9893
# Epoch 14/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0281 - accuracy: 0.9943 - val_loss: 0.1927 - val_accuracy: 0.9620
# Epoch 15/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0256 - accuracy: 0.9944 - val_loss: 0.0720 - val_accuracy: 0.9905
# Epoch 16/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0305 - accuracy: 0.9931 - val_loss: 0.0340 - val_accuracy: 0.9905
# Epoch 17/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0247 - accuracy: 0.9943 - val_loss: 0.0356 - val_accuracy: 0.9920
# Epoch 18/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0289 - accuracy: 0.9940 - val_loss: 0.0517 - val_accuracy: 0.9870
# Epoch 19/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0429 - accuracy: 0.9920 - val_loss: 0.1304 - val_accuracy: 0.9737
# Epoch 20/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0384 - accuracy: 0.9917 - val_loss: 0.0547 - val_accuracy: 0.9880
# Epoch 21/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.0733 - val_accuracy: 0.9880
# Epoch 22/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0144 - accuracy: 0.9967 - val_loss: 0.0390 - val_accuracy: 0.9930
# Epoch 23/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0181 - accuracy: 0.9962 - val_loss: 0.0836 - val_accuracy: 0.9820
# Epoch 24/100
# 282/282 [==============================] - 37s 131ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 0.0682 - val_accuracy: 0.9898
# Epoch 25/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0188 - accuracy: 0.9960 - val_loss: 0.0275 - val_accuracy: 0.9935
# Epoch 26/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0186 - accuracy: 0.9964 - val_loss: 0.0451 - val_accuracy: 0.9925
# Epoch 27/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0257 - accuracy: 0.9954 - val_loss: 0.1158 - val_accuracy: 0.9797
# Epoch 28/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0288 - accuracy: 0.9952 - val_loss: 0.0156 - val_accuracy: 0.9965
# Epoch 29/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0157 - accuracy: 0.9970 - val_loss: 0.0567 - val_accuracy: 0.9880
# Epoch 30/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0140 - accuracy: 0.9972 - val_loss: 0.0503 - val_accuracy: 0.9902
# Epoch 31/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0133 - accuracy: 0.9970 - val_loss: 0.1205 - val_accuracy: 0.9872
# Epoch 32/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0121 - accuracy: 0.9972 - val_loss: 0.0467 - val_accuracy: 0.9927
# Epoch 33/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0281 - accuracy: 0.9957 - val_loss: 0.1486 - val_accuracy: 0.9647
# Epoch 34/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0300 - accuracy: 0.9941 - val_loss: 0.1136 - val_accuracy: 0.9862
# Epoch 35/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0237 - accuracy: 0.9962 - val_loss: 0.0375 - val_accuracy: 0.9935
# Epoch 36/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0140 - accuracy: 0.9974 - val_loss: 0.0331 - val_accuracy: 0.9930
# Epoch 37/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0124 - accuracy: 0.9976 - val_loss: 0.0472 - val_accuracy: 0.9935
# Epoch 38/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.1894 - val_accuracy: 0.9797
# Epoch 39/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0220 - accuracy: 0.9961 - val_loss: 0.0529 - val_accuracy: 0.9915
# Epoch 40/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0145 - accuracy: 0.9976 - val_loss: 0.0999 - val_accuracy: 0.9822
# Epoch 41/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.0471 - val_accuracy: 0.9910
# Epoch 42/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0321 - val_accuracy: 0.9942
# Epoch 43/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0173 - accuracy: 0.9975 - val_loss: 0.0408 - val_accuracy: 0.9942
# Epoch 44/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0150 - accuracy: 0.9977 - val_loss: 0.0741 - val_accuracy: 0.9918
# Epoch 45/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0125 - accuracy: 0.9976 - val_loss: 0.0288 - val_accuracy: 0.9935
# Epoch 46/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.4005 - val_accuracy: 0.9803
# Epoch 47/100
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0261 - accuracy: 0.9966 - val_loss: 0.0464 - val_accuracy: 0.9925
# Epoch 48/100
# 282/282 [==============================] - 36s 129ms/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.0527 - val_accuracy: 0.9925
# Epoch 00048: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.999, Test accuracy: 0.993

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.25 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[0]
#  [1]
#  [1]
#  [1]
#  [1]]
# classified as: [3 6 2 6 6]
# True:          [[5]
#  [5]
#  [6]
#  [6]
#  [6]]
# classified as: [4 8 5 3 5]
