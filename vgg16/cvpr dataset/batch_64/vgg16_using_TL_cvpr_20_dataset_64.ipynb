# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.initializers import glorot_uniform
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/cvpr dataset/train_data20.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/cvpr dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[5]
#  [2]
#  [8]
#  [0]
#  [9]]
# Labels : [[2]
#  [2]
#  [7]
#  [7]
#  [1]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (54000, 32, 32)
# (4000, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 54000 images
# Test Set Size = 4000 images

# %%
# load model
from keras import models    
model_new = models.load_model('/content/drive/MyDrive/model/vgg16_model.h5')
#set trainable false for pretrained model
for layer in model_new.layers[:-8]:
    layer.trainable = False

for l in model_new.layers:
    print(l.name, l.trainable)
# Out:
# input_1 False
# zero_padding2d False
# block1_conv1 False
# batch_normalization False
# activation False
# block1_conv2 False
# batch_normalization_1 False
# activation_1 False
# block1_pool False
# block2_conv1 False
# batch_normalization_2 False
# activation_2 False
# block2_conv2 False
# batch_normalization_3 False
# activation_3 False
# block2_pool False
# block3_conv1 False
# batch_normalization_4 False
# activation_4 False
# block3_conv2 False
# batch_normalization_5 False
# activation_5 False
# block3_conv3 False
# batch_normalization_6 False
# activation_6 False
# block3_pool False
# block4_conv1 False
# batch_normalization_7 False
# activation_7 False
# block4_conv2 False
# batch_normalization_8 False
# activation_8 False
# block4_conv3 False
# batch_normalization_9 False
# activation_9 False
# block4_pool False
# dropout True
# flatten True
# dropout_1 True
# fc1 True
# dropout_2 True
# fc2 True
# dropout_3 True
# predictions True

# %%
model_new.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_7 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_8 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 10)                10250
#
# =================================================================
# Total params: 13,949,642
# Trainable params: 6,304,778
# Non-trainable params: 7,644,864
# _________________________________________________________________

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

#extract layer weight
last_layer = model_new.get_layer('block3_pool')
last_output = last_layer.output

net = Dropout(rate=.2)(last_output)
net = Flatten()(net)
net = Dropout(rate=.5)(net)

net = Dense(2048, activation='relu', name='fc')(net)
net = Dropout(rate=.2)(net)
net = Dense(1024, activation='relu', name='fc2')(net)
net = Dropout(rate=.2)(net)

net = Dense(10, activation='softmax', name='predictions_utl')(net)

# Create model
model_n = Model(inputs = model_new.input, outputs = net, name='vgg16_utl')
model_n.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])

model_n.summary()
# Out:
# Model: "vgg16_utl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  zero_padding2d (ZeroPadding  (None, 38, 38, 1)        0
#  2D)
#
#  block1_conv1 (Conv2D)       (None, 38, 38, 64)        640
#
#  batch_normalization (BatchN  (None, 38, 38, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 38, 38, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 38, 38, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 38, 38, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 19, 19, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 19, 19, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 19, 19, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 19, 19, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 19, 19, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 9, 9, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 9, 9, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 9, 9, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 9, 9, 256)         590080
#
#  batch_normalization_6 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 9, 9, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  dropout (Dropout)           (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  fc (Dense)                  (None, 2048)              8390656
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  predictions_utl (Dense)     (None, 10)                10250
#
# =================================================================
# Total params: 12,238,026
# Trainable params: 10,499,082
# Non-trainable params: 1,738,944
# _________________________________________________________________

# %%
for l in model_n.layers:
    print(l.name, l.trainable)
# Out:
# input_1 False
# zero_padding2d False
# block1_conv1 False
# batch_normalization False
# activation False
# block1_conv2 False
# batch_normalization_1 False
# activation_1 False
# block1_pool False
# block2_conv1 False
# batch_normalization_2 False
# activation_2 False
# block2_conv2 False
# batch_normalization_3 False
# activation_3 False
# block2_pool False
# block3_conv1 False
# batch_normalization_4 False
# activation_4 False
# block3_conv2 False
# batch_normalization_5 False
# activation_5 False
# block3_conv3 False
# batch_normalization_6 False
# activation_6 False
# block3_pool False
# dropout True
# flatten True
# dropout_1 True
# fc True
# dropout_2 True
# fc2 True
# dropout_3 True
# predictions_utl True

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 844/844 [==============================] - 30s 30ms/step - loss: 0.1978 - accuracy: 0.9425 - val_loss: 0.0684 - val_accuracy: 0.9747
# Epoch 2/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0938 - accuracy: 0.9715 - val_loss: 0.0434 - val_accuracy: 0.9835
# Epoch 3/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0832 - accuracy: 0.9738 - val_loss: 0.0560 - val_accuracy: 0.9795
# Epoch 4/100
# 844/844 [==============================] - 26s 30ms/step - loss: 0.0768 - accuracy: 0.9770 - val_loss: 0.0458 - val_accuracy: 0.9860
# Epoch 5/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0714 - accuracy: 0.9793 - val_loss: 0.0478 - val_accuracy: 0.9843
# Epoch 6/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0692 - accuracy: 0.9805 - val_loss: 0.0585 - val_accuracy: 0.9825
# Epoch 28/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0401 - accuracy: 0.9902 - val_loss: 0.0330 - val_accuracy: 0.9910
# Epoch 29/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0449 - accuracy: 0.9900 - val_loss: 0.0200 - val_accuracy: 0.9930
# Epoch 30/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0391 - accuracy: 0.9900 - val_loss: 0.0329 - val_accuracy: 0.9920
# Epoch 31/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0389 - accuracy: 0.9908 - val_loss: 0.0220 - val_accuracy: 0.9923
# Epoch 32/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0384 - accuracy: 0.9904 - val_loss: 0.0361 - val_accuracy: 0.9915
# Epoch 33/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0439 - accuracy: 0.9906 - val_loss: 0.0250 - val_accuracy: 0.9920
# Epoch 34/100
# 844/844 [==============================] - 26s 30ms/step - loss: 0.0396 - accuracy: 0.9909 - val_loss: 0.0369 - val_accuracy: 0.9898
# Epoch 35/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0414 - accuracy: 0.9911 - val_loss: 0.0303 - val_accuracy: 0.9905
# Epoch 36/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0434 - accuracy: 0.9904 - val_loss: 0.0239 - val_accuracy: 0.9930
# Epoch 37/100
# 844/844 [==============================] - 24s 29ms/step - loss: 0.0396 - accuracy: 0.9907 - val_loss: 0.0353 - val_accuracy: 0.9893
# Epoch 38/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0391 - accuracy: 0.9912 - val_loss: 0.0311 - val_accuracy: 0.9880
# Epoch 39/100
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0350 - accuracy: 0.9914 - val_loss: 0.0378 - val_accuracy: 0.9877
# Epoch 00039: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.997, Test accuracy: 0.988

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 98.775 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[0]
#  [1]
#  [1]
#  [1]
#  [1]]
# classified as: [4 4 4 4 4]
# True:          [[2]
#  [3]
#  [3]
#  [3]
#  [3]]
# classified as: [1 6 6 6 0]
