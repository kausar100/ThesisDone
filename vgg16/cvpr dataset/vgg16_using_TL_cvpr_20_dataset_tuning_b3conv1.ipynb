# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import  Dropout, Reshape
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.models import Model

# %%
def reshaping(x):
  return np.reshape(x,(32,32))

a = np.load('/content/drive/MyDrive/cvpr dataset/train_data20.npz')
x_train, y_train = a['arr_0'], a['arr_1']

xx_train = list((map(reshaping,x_train)))
x_train_ = np.array(xx_train)


b = np.load('/content/drive/MyDrive/cvpr dataset/test_data.npz')
x_test, y_test = b['arr_0'], b['arr_1']

xx_test = list((map(reshaping,x_test)))
x_test_ = np.array(xx_test)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train_[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train_[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [[5]
#  [2]
#  [8]
#  [0]
#  [9]]
# Labels : [[2]
#  [2]
#  [7]
#  [7]
#  [1]]

# %%
# Normalizing the input
x_train_ = x_train_.astype('float32')
x_train_/=255

x_test_ = x_test_.astype('float32')
x_test_/=255

print(x_train_.shape)
print(x_test_.shape)
# Out:
# (54000, 32, 32)
# (4000, 32, 32)

# %%
y_train_ = to_categorical(y_train, num_classes=10, dtype='float32')
y_test_ = to_categorical(y_test, num_classes=10, dtype='float32')

print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Train Set Size = 54000 images
# Test Set Size = 4000 images

# %%
# load model
from keras import models    
model_new = models.load_model('/content/drive/MyDrive/model/vgg16_model_test6.h5')
#set trainable false for pretrained model
for layer in model_new.layers[:-30]:
    layer.trainable = False

for l in model_new.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 False
# batch_normalization_10 False
# activation_10 False
# block1_conv2 False
# batch_normalization_11 False
# activation_11 False
# block1_pool False
# block2_conv1 False
# batch_normalization_12 False
# activation_12 False
# block2_conv2 False
# batch_normalization_13 False
# activation_13 False
# block2_pool False
# block3_conv1 True
# batch_normalization_14 True
# activation_14 True
# block3_conv2 True
# batch_normalization_15 True
# activation_15 True
# block3_conv3 True
# batch_normalization_16 True
# activation_16 True
# block3_pool True
# block4_conv1 True
# batch_normalization_17 True
# activation_17 True
# block4_conv2 True
# batch_normalization_18 True
# activation_18 True
# block4_conv3 True
# batch_normalization_19 True
# activation_19 True
# block4_pool True
# dropout_4 True
# flatten_1 True
# dropout_5 True
# fc1 True
# dropout_6 True
# fc2 True
# dropout_7 True
# fc3 True
# dropout_8 True
# predictions True

# %%
model_new.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        640
#
#  batch_normalization_10 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_16 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  batch_normalization_17 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_17 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_18 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_18 (Activation)  (None, 4, 4, 512)         0
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  batch_normalization_19 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_19 (Activation)  (None, 4, 4, 512)         0
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  dropout_4 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout_5 (Dropout)         (None, 2048)              0
#
#  fc1 (Dense)                 (None, 2048)              4196352
#
#  dropout_6 (Dropout)         (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  fc3 (Dense)                 (None, 512)               524800
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 14,469,322
# Trainable params: 14,204,170
# Non-trainable params: 265,152
# _________________________________________________________________

# %%
optimizer = 'adam'
objective = 'categorical_crossentropy'

#extract layer weight
last_layer = model_new.get_layer('block3_pool')
last_output = last_layer.output

net = Dropout(rate=.2)(last_output)
net = Flatten()(net)
net = Dropout(rate=.5)(net)
net = Dense(2048, activation='relu', name='fc')(net)
net = Dropout(rate=.2)(net)
net = Dense(1024, activation='relu', name='fc2')(net)
net = Dropout(rate=.2)(net)
net = Dense(512, activation='relu', name='fc3')(net)
net = Dropout(rate=.2)(net)
net = Dense(10, activation='softmax', name='predictions_utl')(net)

# Create model
model_n = Model(inputs = model_new.input, outputs = net, name='vgg16_utl')
model_n.compile(optimizer=optimizer, loss=objective, metrics=['accuracy'])

model_n.summary()
# Out:
# Model: "vgg16_utl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        640
#
#  batch_normalization_10 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 64)        0
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 64)        0
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 256)         0
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  batch_normalization_16 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 256)         0
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  dropout_24 (Dropout)        (None, 4, 4, 256)         0
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dropout_25 (Dropout)        (None, 4096)              0
#
#  fc (Dense)                  (None, 2048)              8390656
#
#  dropout_26 (Dropout)        (None, 2048)              0
#
#  fc2 (Dense)                 (None, 1024)              2098176
#
#  dropout_27 (Dropout)        (None, 1024)              0
#
#  fc3 (Dense)                 (None, 512)               524800
#
#  dropout_28 (Dropout)        (None, 512)               0
#
#  predictions_utl (Dense)     (None, 10)                5130
#
# =================================================================
# Total params: 12,757,706
# Trainable params: 12,495,626
# Non-trainable params: 262,080
# _________________________________________________________________

# %%
for l in model_n.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 False
# batch_normalization_10 False
# activation_10 False
# block1_conv2 False
# batch_normalization_11 False
# activation_11 False
# block1_pool False
# block2_conv1 False
# batch_normalization_12 False
# activation_12 False
# block2_conv2 False
# batch_normalization_13 False
# activation_13 False
# block2_pool False
# block3_conv1 True
# batch_normalization_14 True
# activation_14 True
# block3_conv2 True
# batch_normalization_15 True
# activation_15 True
# block3_conv3 True
# batch_normalization_16 True
# activation_16 True
# block3_pool True
# dropout_24 True
# flatten_5 True
# dropout_25 True
# fc True
# dropout_26 True
# fc2 True
# dropout_27 True
# fc3 True
# dropout_28 True
# predictions_utl True

# %%
nb_epoch = 100
batch_size = 64

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

ret = model_n.fit(x_train_.reshape((-1,32,32,1)), y_train_, 
                  epochs=nb_epoch, batch_size=batch_size, verbose=1,
                  #validation_split=0.3,
                  validation_data=(x_test_, y_test_),
                  callbacks=[es])
# Out:
# Epoch 1/100
# 844/844 [==============================] - 31s 35ms/step - loss: 0.1665 - accuracy: 0.9544 - val_loss: 0.0356 - val_accuracy: 0.9895
# Epoch 2/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0518 - accuracy: 0.9858 - val_loss: 0.0230 - val_accuracy: 0.9925
# Epoch 3/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0400 - accuracy: 0.9901 - val_loss: 0.0192 - val_accuracy: 0.9940
# Epoch 4/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0309 - accuracy: 0.9922 - val_loss: 0.0506 - val_accuracy: 0.9887
# Epoch 5/100
# 844/844 [==============================] - 30s 35ms/step - loss: 0.0301 - accuracy: 0.9929 - val_loss: 0.0372 - val_accuracy: 0.9895
# Epoch 6/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0260 - accuracy: 0.9940 - val_loss: 0.0322 - val_accuracy: 0.9910
# Epoch 7/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0259 - accuracy: 0.9944 - val_loss: 0.0419 - val_accuracy: 0.9918
# Epoch 8/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0246 - accuracy: 0.9947 - val_loss: 0.0390 - val_accuracy: 0.9940
# Epoch 9/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0238 - accuracy: 0.9953 - val_loss: 0.0105 - val_accuracy: 0.9967
# Epoch 10/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0175 - accuracy: 0.9962 - val_loss: 0.0267 - val_accuracy: 0.9937
# Epoch 11/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0193 - accuracy: 0.9964 - val_loss: 0.0373 - val_accuracy: 0.9930
# Epoch 12/100
# 844/844 [==============================] - 30s 35ms/step - loss: 0.0192 - accuracy: 0.9965 - val_loss: 0.0225 - val_accuracy: 0.9950
# Epoch 13/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0177 - accuracy: 0.9967 - val_loss: 0.0097 - val_accuracy: 0.9975
# Epoch 14/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0164 - accuracy: 0.9974 - val_loss: 0.0504 - val_accuracy: 0.9950
# Epoch 15/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0177 - accuracy: 0.9966 - val_loss: 0.0462 - val_accuracy: 0.9945
# Epoch 16/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0209 - accuracy: 0.9967 - val_loss: 0.0212 - val_accuracy: 0.9960
# Epoch 17/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0320 - val_accuracy: 0.9955
# Epoch 18/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0176 - accuracy: 0.9971 - val_loss: 0.0365 - val_accuracy: 0.9955
# Epoch 19/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0199 - accuracy: 0.9971 - val_loss: 0.0253 - val_accuracy: 0.9977
# Epoch 20/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0124 - accuracy: 0.9978 - val_loss: 0.0189 - val_accuracy: 0.9975
# Epoch 21/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0118 - accuracy: 0.9976 - val_loss: 0.0114 - val_accuracy: 0.9977
# Epoch 22/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 0.0226 - val_accuracy: 0.9975
# Epoch 23/100
# 844/844 [==============================] - 29s 35ms/step - loss: 0.0155 - accuracy: 0.9977 - val_loss: 0.0481 - val_accuracy: 0.9945
# Epoch 00023: early stopping

# %%
plt.plot(ret.history['loss'], label='train loss')
plt.plot(ret.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
plt.plot(ret.history['accuracy'], label='train acc')
plt.plot(ret.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
# evaluate the model
_, train_acc = model_n.evaluate(x_train_, y_train_, verbose=0)
_, test_acc = model_n.evaluate(x_test_, y_test_, verbose=0)
print('Train accuracy: %.3f, Test accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train accuracy: 0.999, Test accuracy: 0.994

# %%
predictions = model_n.predict(x_test_.reshape((-1,32,32,1)), verbose=0)

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.45 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[1]
#  [5]
#  [5]
#  [5]
#  [5]]
# classified as: [2 0 6 6 6]
# True:          [[5]
#  [5]
#  [5]
#  [5]
#  [5]]
# classified as: [6 6 1 6 6]
